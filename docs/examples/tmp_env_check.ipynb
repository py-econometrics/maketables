# %% [raw]
# ---
# title: env-check
# format:
#   typst: default
# execute:
#   echo: true
# ---

# %%
import os
print("QEI:", os.environ.get("QUARTO_EXECUTE_INFO"))
print("QUARTO_KEYS:", sorted([k for k in os.environ if k.startswith("QUARTO")]))
